# %% [markdown]
# # Plotting Results

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd

# %%
plt.rcParams.clear()
plt.style.use(['science', 'no-latex'])

# %% [markdown]
# ## Geometry: Square

# %%
square_entropy_eta_2 = pd.read_csv("data/entropy_values_square_100_2.csv")
square_entropy_eta_3 = pd.read_csv("data/entropy_values_square_100_3.csv")
square_entropy_eta_4 = pd.read_csv("data/entropy_values_square_100_4.csv")

# %%
plt.figure(figsize=(6,4))
plt.plot(np.array(square_entropy_eta_2['r0']), np.array(square_entropy_eta_2['entropy']), label=r'$\eta=2$', color='C0')
plt.plot(np.array(square_entropy_eta_3['r0']), np.array(square_entropy_eta_3['entropy']), label=r'$\eta=3$', color='C2')
plt.plot(np.array(square_entropy_eta_4['r0']), np.array(square_entropy_eta_4['entropy']), label=r'$\eta=4$', color='C1')
plt.xlabel(r'$r_0$')
plt.ylabel(r'$H(\mathcal{G})$')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(np.array(square_entropy_eta_2['r0']), np.array(square_entropy_eta_2['entropy']), label=r'$\eta=2$', color='C0')
plt.plot(np.array(square_entropy_eta_3['r0']), np.array(square_entropy_eta_3['entropy'])*3/2, label=r'$\eta=3$', color='C2')
plt.plot(np.array(square_entropy_eta_4['r0']), np.array(square_entropy_eta_4['entropy'])*2, label=r'$\eta=4$', color='C1')
plt.xlabel(r'$r_0$')
plt.ylabel(r'$H(\mathcal{G})$')
plt.legend()
plt.show()

# %%
square_mass_small = pd.read_csv("data/mass_values_square_0.100000_2.csv")
square_mass_medium = pd.read_csv("data/mass_values_square_0.713000_2.csv")
square_mass_large = pd.read_csv("data/mass_values_square_1.000000_2.csv")

# %%
plt.figure(figsize=(5,5))
Z = np.array(square_mass_small['mass']).reshape((len(set(square_mass_small['x'])),len(set(square_mass_small['x']))))
plt.imshow(Z, extent=(np.min(square_mass_small['x']), np.max(square_mass_small['x']), np.min(square_mass_small['y']), np.max(square_mass_small['y'])))
plt.title(r"$r_0 = 0.1$")
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(5,5))
Z = np.array(square_mass_medium['mass']).reshape((100,100))
plt.imshow(Z, extent=(np.min(square_mass_medium['x']), np.max(square_mass_medium['x']), np.min(square_mass_medium['y']), np.max(square_mass_medium['y'])))
plt.title(r"$r_0 = 0.713$")
plt.show()

# %%
plt.figure(figsize=(5,5))
Z = np.array(square_mass_large['mass']).reshape((100,100))
plt.imshow(Z, extent=(np.min(square_mass_large['x']), np.max(square_mass_large['x']), np.min(square_mass_large['y']), np.max(square_mass_large['y'])))
plt.title(r"$r_0 = 1.0$")
plt.show()

# %% [markdown]
# ## Geometry: Wedge of different angles

# %%
wedge_eta_2_theta_pi_2 = pd.read_csv("data/entropy_values_wedge_1.570000_100_2.csv")
wedge_eta_2_theta_pi_4 = pd.read_csv("data/entropy_values_wedge_0.785000_100_2.csv")
wedge_eta_2_theta_pi_8 = pd.read_csv("data/entropy_values_wedge_0.392600_100_2.csv")

# %%
plt.figure(figsize=(6,4))
plt.rcParams.update({'font.size': 15})
plt.plot(np.array(wedge_eta_2_theta_pi_2['r0']), np.array(wedge_eta_2_theta_pi_2['entropy']), label=r'$\theta = \frac{\pi}{2}$', color='C2')
plt.plot(np.array(wedge_eta_2_theta_pi_4['r0']), np.array(wedge_eta_2_theta_pi_4['entropy']), label=r'$\theta = \frac{\pi}{4}$', color='C0')
plt.plot(np.array(wedge_eta_2_theta_pi_8['r0']), np.array(wedge_eta_2_theta_pi_8['entropy']), label=r'$\theta = \frac{\pi}{8}$', color='C1')
plt.xlabel(r'$r_0$')
plt.ylabel(r'$H(\mathcal{G})$')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(np.array(wedge_eta_2_theta_pi_2['r0']), np.array(wedge_eta_2_theta_pi_2['entropy']), label=r'$\theta = \frac{\pi}{2}$', color='C2')
plt.plot(np.array(wedge_eta_2_theta_pi_4['r0'])*np.sqrt(2), np.array(wedge_eta_2_theta_pi_4['entropy']), label=r'$\theta = \frac{\pi}{4}$', color='C0')
plt.plot(np.array(wedge_eta_2_theta_pi_8['r0'])*2, np.array(wedge_eta_2_theta_pi_8['entropy']), label=r'$\theta = \frac{\pi}{8}$', color='C1')

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel(r'$r_0/\sqrt{2\theta/\pi}$', fontsize=15)
plt.ylabel(r'$H(\mathcal{G})$', fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
wedge_eta_3_theta_pi_2 = pd.read_csv("data/entropy_values_wedge_1.570000_100_3.csv")
wedge_eta_3_theta_pi_4 = pd.read_csv("data/entropy_values_wedge_0.785000_100_3.csv")
wedge_eta_3_theta_pi_8 = pd.read_csv("data/entropy_values_wedge_0.392600_100_3.csv")

# %%
plt.figure(figsize=(6,4))
plt.plot(np.array(wedge_eta_3_theta_pi_2['r0']), np.array(wedge_eta_3_theta_pi_2['entropy']), label=r'$\theta = \frac{\pi}{2}$', color='C2')
plt.plot(np.array(wedge_eta_3_theta_pi_4['r0'])*np.sqrt(2), np.array(wedge_eta_3_theta_pi_4['entropy']), label=r'$\theta = \frac{\pi}{4}$', color='C0')
plt.plot(np.array(wedge_eta_3_theta_pi_8['r0'])*2, np.array(wedge_eta_3_theta_pi_8['entropy']), label=r'$\theta = \frac{\pi}{8}$', color='C1')

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel(r'$r_0$', fontsize=15)
plt.ylabel(r'$H(\mathcal{G})$', fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# ### Entropy mass

# %%
wedge_mass_0_05_2 = pd.read_csv("data/mass_values_wedge_0.783000_0.050000_2.csv")
wedge_mass_0_5_2 = pd.read_csv("data/mass_values_wedge_0.783000_0.500000_2.csv")
wedge_mass_1_2 = pd.read_csv("data/mass_values_wedge_0.783000_1.000000_2.csv")

# %%
wedge_mass_0_05_2['x'] = np.array(wedge_mass_0_05_2['r']) * np.cos(np.array(wedge_mass_0_05_2['theta']))
wedge_mass_0_05_2['y'] = np.array(wedge_mass_0_05_2['r']) * np.sin(np.array(wedge_mass_0_05_2['theta']))

wedge_mass_0_5_2['x'] = np.array(wedge_mass_0_5_2['r']) * np.cos(np.array(wedge_mass_0_5_2['theta']))
wedge_mass_0_5_2['y'] = np.array(wedge_mass_0_5_2['r']) * np.sin(np.array(wedge_mass_0_5_2['theta']))

wedge_mass_1_2['x'] = np.array(wedge_mass_1_2['r']) * np.cos(np.array(wedge_mass_1_2['theta']))
wedge_mass_1_2['y'] = np.array(wedge_mass_1_2['r']) * np.sin(np.array(wedge_mass_1_2['theta']))

# %%
fig, ax = plt.subplots(1,3,figsize=(15,4))
ax[0].scatter(wedge_mass_0_05_2['x'], wedge_mass_0_05_2['y'], c=wedge_mass_0_05_2['mass'], s=1, cmap='viridis')
ax[1].scatter(wedge_mass_0_5_2['x'], wedge_mass_0_5_2['y'], c=wedge_mass_0_5_2['mass'],s=1, cmap='viridis')
ax[2].scatter(wedge_mass_1_2['x'], wedge_mass_1_2['y'], c=wedge_mass_1_2['mass'],s=1, cmap='viridis')
ax[0].set_title(r"$r_0=0.05$", fontsize=18)
ax[1].set_title(r"$r_0=0.5$", fontsize=18)
ax[2].set_title(r"$r_0=1$", fontsize=18)
ax[0].axis('off')
ax[1].axis('off')
ax[2].axis('off')
ax[0].axis('equal')
ax[1].axis('equal')
ax[2].axis('equal')

cb0 = fig.colorbar(ax[0].collections[0], ax=ax[0], shrink=0.8)
cb1 = fig.colorbar(ax[1].collections[0], ax=ax[1], shrink=0.8)
cb2 = fig.colorbar(ax[2].collections[0], ax=ax[2], shrink=0.8)

cb0.ax.tick_params(labelsize=18)
cb1.ax.tick_params(labelsize=18)
cb2.ax.tick_params(labelsize=18)

plt.tight_layout()

#ax[0].colorbar()
plt.show()

# %% [markdown]
# ## Geometry: Annulus

# %%
annulus_eta_2_R_05 = pd.read_csv("data/entropy_values_annulus_0.500000_100_2.csv")
annulus_eta_2_R_025 = pd.read_csv("data/entropy_values_annulus_0.250000_100_2.csv")
annulus_eta_2_R_005 = pd.read_csv("data/entropy_values_annulus_0.050000_100_2.csv")
annulus_eta_2_R_075 = pd.read_csv("data/entropy_values_annulus_0.750000_100_2.csv")
annulus_eta_2_R_0 = pd.read_csv("data/entropy_values_annulus_0.000000_100_2.csv")
annulus_eta_2_R_09 = pd.read_csv("data/entropy_values_annulus_0.900000_100_2.csv")

# %%
plt.figure(figsize=(6,4))
plt.rcParams.update({'font.size':15})
#plt.plot(np.array(annulus_eta_2_R_0['r0']), np.array(annulus_eta_2_R_0['entropy']), label=r'$R = 0$', color='0')
plt.plot(np.array(annulus_eta_2_R_005['r0']), np.array(annulus_eta_2_R_005['entropy']), label=r'$R = \frac{1}{20}$', color='C1')
#plt.plot(np.array(annulus_eta_2_R_025['r0']), np.array(annulus_eta_2_R_025['entropy']), label=r'$R = \frac{1}{4}$', color='C2')
plt.plot(np.array(annulus_eta_2_R_05['r0']), np.array(annulus_eta_2_R_05['entropy']), label=r'$R = \frac{1}{2}$', color='C3')
#plt.plot(np.array(annulus_eta_2_R_075['r0']), np.array(annulus_eta_2_R_075['entropy']), label=r'$R = \frac{3}{4}$', color='C4')
plt.plot(np.array(annulus_eta_2_R_09['r0']), np.array(annulus_eta_2_R_09['entropy']), label=r'$R = \frac{9}{10}$', color='C5')
plt.xlabel(r'$r_0$')
plt.ylabel(r'$H(\mathcal{G})$')
plt.legend()
plt.show()

# %%
annulus_mass_1 = pd.read_csv("data/mass_values_annulus_0.800000_0.010000_2.csv")
annulus_mass_2 = pd.read_csv("data/mass_values_annulus_0.800000_0.200000_2.csv")
annulus_mass_3 = pd.read_csv("data/mass_values_annulus_0.800000_0.500000_2.csv")

# %%
fig, ax = plt.subplots(1,3,figsize=(18,4))

ax[0].scatter(np.array(annulus_mass_1['r']) * np.cos(np.array(annulus_mass_1['theta'])), 
            np.array(annulus_mass_1['r']) * np.sin(np.array(annulus_mass_1['theta'])), 
            c=np.array(annulus_mass_1['mass']), s=1, cmap='viridis')

ax[1].scatter(np.array(annulus_mass_2['r']) * np.cos(np.array(annulus_mass_2['theta'])), 
            np.array(annulus_mass_2['r']) * np.sin(np.array(annulus_mass_2['theta'])), 
            c=np.array(annulus_mass_2['mass']), s=1, cmap='viridis')

ax[2].scatter(np.array(annulus_mass_3['r']) * np.cos(np.array(annulus_mass_3['theta'])), 
            np.array(annulus_mass_3['r']) * np.sin(np.array(annulus_mass_3['theta'])), 
            c=np.array(annulus_mass_3['mass']), s=1, cmap='viridis')

ax[0].set_title(r"$r_0 = 0.01$")
ax[1].set_title(r"$r_0 = 0.2$")
ax[2].set_title(r"$r_0 = 0.5$")

ax[0].axis('equal')
ax[0].axis('off')

ax[1].axis('equal')
ax[1].axis('off')

ax[2].axis('equal')
ax[2].axis('off')

cb0 = fig.colorbar(ax[0].collections[0], ax=ax[0], shrink=0.8)
cb1 = fig.colorbar(ax[1].collections[0], ax=ax[1], shrink=0.8)
cb2 = fig.colorbar(ax[2].collections[0], ax=ax[2], shrink=0.8)

cb0.ax.tick_params(labelsize=18)
cb1.ax.tick_params(labelsize=18)
cb2.ax.tick_params(labelsize=18)

plt.tight_layout()

# %% [markdown]
# ## Geometry: Cantor Set

# %%
cantor_entropy_6_1_4_4 = pd.read_csv("data/entropy_values_cantor_6_0.250000_500_4.csv")
cantor_entropy_6_1_3_4 = pd.read_csv("data/entropy_values_cantor_6_0.333000_500_4.csv")
cantor_entropy_6_1_6_4 = pd.read_csv("data/entropy_values_cantor_6_0.166000_500_4.csv")
cantor_entropy_6_1_10_4 = pd.read_csv("data/entropy_values_cantor_6_0.100000_500_4.csv")

# %%
# finer plots
cantor_entropy_1_10 = pd.read_csv("data/entropy_values_cantor_7_0.100000_100_4.csv")
cantor_entropy_1_4 = pd.read_csv("data/entropy_values_cantor_6_0.250000_100_4.csv")
cantor_entropy_1_6 = pd.read_csv("data/entropy_values_cantor_7_0.166000_100_4.csv")
cantor_entropy_1_3 = pd.read_csv("data/entropy_values_cantor_7_0.333000_100_4.csv")

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4.5))
ax[0].plot(np.array(cantor_entropy_6_1_3_4['r0']), np.array(cantor_entropy_6_1_3_4['entropy']), label=r'$\lambda=3$', color='C0')
ax[0].plot(np.array(cantor_entropy_6_1_4_4['r0']), np.array(cantor_entropy_6_1_4_4['entropy']), label=r'$\lambda=4$', color='C1')
ax[0].plot(np.array(cantor_entropy_6_1_6_4['r0']), np.array(cantor_entropy_6_1_6_4['entropy']), label=r'$\lambda= 6$', color='C2')
ax[0].plot(np.array(cantor_entropy_6_1_10_4['r0']), np.array(cantor_entropy_6_1_10_4['entropy']), label=r'$\lambda=10$', color='C3')
ax[0].set_xlabel(r'$r_0$')
ax[0].set_ylabel(r'$H(\mathcal{G})$')

ax[1].loglog(cantor_entropy_1_3['r0'], cantor_entropy_1_3['entropy'], label=r'$\lambda= 3$', color='C0')
ax[1].loglog(cantor_entropy_6_1_4_4['r0'], cantor_entropy_6_1_4_4['entropy'], label=r'$\lambda= 4$', color='C1')
ax[1].loglog(cantor_entropy_6_1_6_4['r0'], cantor_entropy_6_1_6_4['entropy'], label=r'$\lambda= 6$', color='C2')
ax[1].loglog(cantor_entropy_6_1_10_4['r0'], cantor_entropy_6_1_10_4['entropy'], label=r'$\lambda= 10$', color='C3')
ax[1].set_xlabel(r'$r_0$', fontsize=18)
ax[1].set_ylabel(r'$H(\mathcal{G})$', fontsize=18)
ax[1].set_xlim(0.001,1)
ax[1].set_ylim(0.00001,1)
ax[1].legend()
# ax[1].set_yscale('log')
# ax[1].set_xscale('log')

plt.tight_layout()
ax[0].legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.loglog(cantor_entropy_1_3['r0'], cantor_entropy_1_3['entropy'], label=r'$\lambda= 3$', color='C0')
plt.loglog(cantor_entropy_1_4['r0'], cantor_entropy_1_4['entropy'], label=r'$\lambda= 4$', color='C1')
plt.loglog(cantor_entropy_1_6['r0'], cantor_entropy_1_6['entropy'], label=r'$\lambda= 6$', color='C2')
plt.loglog(cantor_entropy_1_10['r0'], cantor_entropy_1_10['entropy'], label=r'$\lambda= 10$', color='C3')
plt.xlabel(r'$r_0$', fontsize=18)
plt.ylabel(r'$H(\mathcal{G})$', fontsize=18)
plt.xlim(0.001,1)
plt.ylim(0.00001,1)
plt.legend(loc='lower right', ncol=2)
plt.show()
